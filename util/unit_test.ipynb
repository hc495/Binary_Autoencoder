# %%
from transformers import AutoTokenizer

tokenizer1 = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")
tokenizer2 = AutoTokenizer.from_pretrained("BAAI/bge-m3")

# %%
from transformers import AutoModel

# 加载模型
model2 = AutoModel.from_pretrained("BAAI/bge-m3")

# %%
tknzd = tokenizer2("Hello, world! Test test", return_tensors="pt")

# %%
model2(tknzd['input_ids'], output_hidden_states=True)
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[-0.7977,  0.4981, -1.2719,  ...,  0.3773, -0.8096,  0.0710],
#          [ 0.0154, -0.1872, -0.6752,  ...,  0.9367, -0.3630,  0.5663],
#          [-0.3920,  0.2410, -0.8179,  ...,  0.7630, -0.4738,  0.2890],
#          ...,
#          [ 0.5226,  0.6124, -0.9696,  ...,  0.2466, -0.9643, -0.4254],
#          [ 0.3163,  0.5585, -0.7626,  ...,  0.2939, -0.6344, -0.3879],
#          [-0.0860,  0.4025, -0.1661,  ...,  1.6420, -1.2382,  0.3775]]],
#        grad_fn=<NativeLayerNormBackward0>), pooler_output=tensor([[-0.8629,  0.4212,  0.5576,  ...,  0.1440,  0.7055,  0.0275]],
#        grad_fn=<TanhBackward0>), hidden_states=(tensor([[[-0.2016, -0.0079, -0.2226,  ..., -0.4545, -0.6055, -0.8371],
#          [-0.0017, -0.4878,  0.9206,  ...,  0.3853,  0.5182, -0.5145],
#          [ 0.7792,  0.2234, -0.3300,  ...,  0.8322,  0.1571,  0.9363],
#          ...,
# ...

# %%
tokenizer2("Hello, world! Test test", return_tensors="pt")
# Out:
# {'input_ids': tensor([[    0, 35378,     4,  8999,    38,  8647,  3034,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1, 1]])}

# %%
find_tokenized_position_in_another_tokenizer(
    "Hello, world! Test test", tokenizer1, 5, tokenizer2
)
# Out:
# Hello, world! Test
# 6
